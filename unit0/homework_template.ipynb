# %% [markdown]
# # Template for submitting homework

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The first homeworks assignment is relative simple. I have to describe first in the introduction what this whole notebook
# is about. The first time using the Jupyter Notebook one can easily get confused because we have different types of text cells. The Markdown cell (this cell with the introduction is a cell of type *Markdown*) is not part of the Python programming language. It is used to document the computer code that is embedded in the cells of type *Code*.
# So in the following sections I give you some examples how you can give some structure and organization to your Notebooks. The homework will have to follow this general structure.
#
# **Every homework must include**
# 1. an introduction that describes the problem and gives background information
# 2. a section on data and code (e.g. packages, functions, previous scripts, external resources) that you use in your homework
# 3. a section labeled results, which can include of course code that generates the results
# 4. a summary and with concluding remarks and/or specific answers to the assigned homework questions

# %% [markdown]
# ## 2. Data and code used (and other resources)

# %% [markdown]
# Here is an example text that you would go into this section:
# *In this homework we are given three different data files (...)
# As a starting point for my code development I use the code from unit X.X (from notebook so and so)
# Further, I found some good information on how to apply text formatting in with the Markdown text
# [here on this web page](http://nestacms.com/docs/creating-content/markdown-cheat-sheet)*
#
# Please make use subtitles/subsections to further organize your Notebook.
#
# ### 2.1 List of packages and functions
#
# Apart from the standard python packages I use the package called "fancypython" ([link to web page](http://www.google.com)) (this is does not exist of course, just to give you an idea)

# %% [markdown]
# ## 3. Code development

# %% [markdown]
# NA  (<-If a section would really not apply then you can just enter NA)

# %% [markdown]
# ## 4. Results
#
# In this template there is nothing really that I need to code up. And no real statistical results to present here either.
# Instead I just show here some features of the combined use of markdown cells and some code cells with Python.

# %% [markdown]
# ### 4.1 Adding images (local files or hyperlinked online image files)
#
# This package here allows me to use python code to show a image.

# %%
from IPython.display import Image
Image("earth.jpg",width=300) # Image is a function that we call to display the image

# %%
# If you want you can put comments into Python code using this leading # character
gif="little_animation.gif"  # variable gif is assigned to a string 
Image(gif)

# %%
# You can easily link in online content (images)
source="https://scripps.ucsd.edu/programs/keelingcurve/wp-content/plugins/sio-bluemoon/graphs/mlo_one_month.png"
Image(source, width="50%")

# %% [markdown]
# ## 4.2 Rendering equations with python (optional)
#
# This is a bit more difficult to do because you need to know the "markdown" language used to describe mathematical symbols.But in the end with simple equations (and we do not use equations not all the time) can be generated with little extra knowledge.

# %%
from IPython.display import display, Math, Latex
display(Math(r'\Large c=\sqrt{a^2 + b^2}'))
display(Math(r'\Large \bar{x}= \frac{1}{n} \sum_{i=1}^{n}x_i'))
# Out:
# $$\Large c=\sqrt{a^2 + b^2}$$
# $$\Large \bar{x}= \frac{1}{n} \sum_{i=1}^{n}x_i$$

# %% [markdown]
# ## 4.3 And just for fun (well maybe your want to reference your youtube sources this way?)
#
# Tip: run the cell several times. Can you guess how the code works?

# %%
from IPython.display import YouTubeVideo
import numpy as np

random_value=np.random.uniform(size=1)
print(random_value)
if random_value>0.5:
    videostream="rl5DaFbLc60"
else:
    videostream="AjplZXgodhs"

YouTubeVideo(videostream)
# Out:
# [0.72413848]

# %% [markdown]
# ## 5. Summary and Concluding remarks
#
# So, this was it. In summary, you can find plenty of good youtube videos, tutorials and example web pages that explain the elements use in this notebook that give a more appealing layout to the Notebook. Please remember that you use this template for the organization of your homeworks. The first time we will be giving you feedback. Points will be deducted when you do not make use of markup cells, text highlighting (font modifiers such as *italics* "**bold**" and #Huge ##Large ###somewhat larger) structures. More options exist of course to change the layout. Feel free to explore and give your notebook an invididual touch.
#
# By the way if you study the examples on markdown cells (see References below) you will find ways to show images, videos, and equations right inside your markdown cells. No Python required (But can you think of situations where Python might be a more flexible way of doing it?)

# %% [markdown]
# ### 6. Notes
# Oh yes, please add a note here, and give feedback to us such as:
#
# "I had a lot of trouble with the coding in this homework. The more support or tips would have helped me to find the lines of code that I needed to change for this exercise."
#
# "First, I did not know where to start solving the problem, but once I understood how to call the function, it was easy. This exercise helped my to understand concept of functions, and also the meaning of probability density functions."

# %% [markdown]
# ### 7. References and links (IMPORTANT THAT YOU REFER TO THE SOURCES)
#
# Additional links:
#
# - [Markdown Cells](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)
#
# - [A compact list of markdown elements](https://www.ibm.com/support/knowledgecenter/SSQNUZ_current/com.ibm.icpdata.doc/dsx/markd-jupyter.html)
