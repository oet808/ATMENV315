# %%
#OET05/15
#add path to student directory
import os
userid='ak771891'
subdir='ENV315/final_project/'
spath='/home11/ugrad/2020/'+userid+'/'+subdir

print(spath)
result=os.popen("ls "+spath)
for line in result:
    print(line[:-1])
# Out:
# /home11/ugrad/2020/ak771891/ENV315/final_project/
# 1980-1989_CO_Cambria.csv
# 1980-1989_CO_Queens.csv
# 1980_CO_Cambria.csv
# 1980_CO_Queens.csv
# 1981_CO_Cambria.csv
# 1981_CO_Queens.csv
# 1982_CO_Cambria.csv
# 1982_CO_Queens.csv
# 1983_CO_Cambria.csv
# 1984_CO_Cambria.csv
# 1985_CO_Cambria.csv
# 1986_CO_Cambria.csv
# 1987_CO_Cambria.csv
# 1988_CO_Cambria.csv
# 1988_CO_Queens.csv
# 1989_CO_Cambria.csv
# 1989_CO_Queens.csv
# 1990-1999_CO_Cambria.csv
# 1990-1999_CO_Queens.csv
# 1990_CO_Cambria.csv
# 1990_CO_Queens.csv
# 1991_CO_Cambria.csv
# 1992_CO_Cambria.csv
# 1993_CO_Cambria.csv
# 1994_CO_Cambria.csv
# 1995_CO_Cambria.csv
# 1996_CO_Cambria.csv
# 1997_CO_Cambria.csv
# 1998_CO_Cambria.csv
# 1998_CO_Queens.csv
# 1999_CO_Cambria.csv
# 1999_CO_Queens.csv
# 2000-2009_CO_Cambria.csv
# 2000-2009_CO_Queens.csv
# 2000_CO_Cambria.csv
# 2000_CO_Queens.csv
# 2001_CO_Cambria.csv
# 2001_CO_Queens.csv
# 2002_CO_Cambria.csv
# 2002_CO_Queens.csv
# 2003_CO_Cambria.csv
# 2003_CO_Queens.csv
# ...
