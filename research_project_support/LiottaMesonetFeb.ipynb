# %%
# %matplotlib inline

import numpy as np 
from numpy import genfromtxt 
import matplotlib.pyplot as plt
import datetime as dt

# %%
data1= genfromtxt("../data/202002.csv",delimiter=',',skip_header=1)
print(type(data1))
print(data1)
# Out:
# <class 'numpy.ndarray'>
# [[  nan   nan  -1.3 ...   3.2 168.1   0. ]
#  [  nan   nan  -1.3 ...   1.9 155.7   0. ]
#  [  nan   nan  -1.2 ...   2.1 157.8   0. ]
#  ...
#  [  nan   nan  -4.6 ...   9.8 267.1   0. ]
#  [  nan   nan  -4.5 ...   9.1 266.6   0. ]
#  [  nan   nan  -4.5 ...   9.2 275.4   0. ]]

# %% [markdown]
# # 126 Stations
# # 696 Rows of data per station

# %%
#Saranac Station
SARA = data1[63336:64031]
SARAavgtemp = SARA[:,4]
SARAhum = SARA[:,7]
SARAwnd = SARA[:,12]
plt.plot(SARAwnd)
plt.plot(SARAavgtemp)

SARAa = data1[63486:63636]
SARAahum = SARAa[:,7]
SARAawnd = SARAa[:,12]

# %%
#Cold Brook Station
COLD = data1[20184:20879]
COLDavgtemp = COLD[:,4]
COLDhum = COLD[:,7]
COLDwnd = COLD[:,12]
plt.plot(COLDwnd)
plt.plot(COLDavgtemp)
plt.plot(COLDhum)

COLDa = data1[20334:20484]
COLDahum = COLDa[:,7]
COLDawnd = COLDa[:,12]

# %%
plt.plot(SARAhum, label="SARA(N)")
plt.plot(COLDhum, label="COLD(S)")
plt.legend()

# %%
plt.plot(SARAahum,label="SARA Hum")
plt.plot(SARAawnd,label="SARA Wnd")
plt.plot(COLDahum,label="COLD Hum")
plt.plot(COLDawnd,label="COLD Wnd")
plt.legend()

# %%
SARA = data1[63551:63574]
SARAhum = SARA[:,7]
SARAwnd = SARA[:,12]

COLD = data1[20399:20422]
COLDhum = COLD[:,7]
COLDwnd = COLD[:,12]

fig=plt.figure(figsize=(15,6))
plt.plot(SARAhum,label="SARA Humidity")
plt.plot(SARAwnd,label="SARA Wind Direction")
plt.plot(COLDhum,label="COLD Humidity")
plt.plot(COLDwnd,label="COLD Wind Direction")
plt.title("Humidity and Wind Direction February 10th")
plt.xlabel("Hour")
plt.ylabel("Direction (degrees) or Humidity (%)")
plt.legend()

# %%
SARA = data1[63911:63934]
SARAhum = SARA[:,7]
SARAwnd = SARA[:,12]

COLD = data1[20759:20782]
COLDhum = COLD[:,7]
COLDwnd = COLD[:,12]

fig=plt.figure(figsize=(15,6))
plt.plot(SARAhum,label="SARA Humidity")
plt.plot(SARAwnd,label="SARA Wind Direction")
plt.plot(COLDhum,label="COLD Humidity")
plt.plot(COLDwnd,label="COLD Wind Direction")
plt.title("Humidity and Wind Direction February 25th")
plt.xlabel("Hour")
plt.ylabel("Direction (degrees) or Humidity (%)")
plt.legend()

# %% [markdown]
# # Whiteface

# %%
WFMB_T = data1[84216:84911]
WFMB = data1[84316:84416]
WFMBavgtemp = WFMB[:,4]
WFMBhum = WFMB[:,7]
WFMBwnd = WFMB[:,12]
plt.plot(WFMBwnd)
#plt.plot(WFMBavgtemp)
plt.plot(WFMBhum)
